# %%
import pandas as pd
import researchpy as rp
import seaborn as sns
import numpy as np

import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp

# %%
# load data
measurement = [
    32, 48, 538, 52, 244, 998, 59, 536, 1348,
    53, 81, 1901, 112, 776, 3621, 121, 1879, 4639,
    142, 197, 5609, 262, 2625, 10012, 980, 5698, 12880,
    49, 67, 789, 79, 390, 1373, 85, 814, 1693,
    100, 134, 3152, 164, 1255, 4912, 206, 3394, 5838,
    233, 350, 9100, 458, 3688, 13531, 1633, 10022, 17117,
    62, 100, 1103, 111, 480, 1782, 111, 839, 2190,
    96, 245, 2807, 237, 1502, 6007, 286, 3092, 7654,
    265, 2012, 12429, 517, 4870, 18602, 1728, 8834, 23134
]

# log-transform 
measurement = np.log10(measurement)

# factors and levels
algorithm = ['lruv', 'fifo', 'rand']
program = ['small', 'medium', 'large']
arrangement = ['group', 'freqy', 'alpha']
memory = ['24p', '20p', '16p']

factor1 = np.tile(np.repeat(memory,1), [27,1])
factor1 = factor1.reshape(factor1.shape[0]*factor1.shape[1],)

factor2 = np.tile(np.repeat(arrangement,3), [9,1])
factor2 = factor2.reshape(factor2.shape[0]*factor2.shape[1],)

factor3 = np.tile(np.repeat(program,9), [3,1])
factor3 = factor3.reshape(factor3.shape[0]*factor3.shape[1],)

factor4 = np.tile(np.repeat(algorithm,27), [1,1])
factor4 = factor4.reshape(factor4.shape[0]*factor4.shape[1],)


# construct dataframe
df = pd.DataFrame({
    "memory": factor1,
    "arrangement": factor2,
    "program": factor3,
    "algorithm": factor4,
    "measurement": measurement,
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   memory       81 non-null     object
#  1   arrangement  81 non-null     object
#  2   program      81 non-null     object
#  3   algorithm    81 non-null     object
#  4   measurement  81 non-null     float64
# dtypes: float64(1), object(4)
# memory usage: 3.3+ KB

# %%
df[:10]
# Out:
#   memory arrangement program algorithm  measurement
# 0    24p       group   small      lruv     1.505150
# 1    20p       group   small      lruv     1.681241
# 2    16p       group   small      lruv     2.730782
# 3    24p       freqy   small      lruv     1.716003
# 4    20p       freqy   small      lruv     2.387390
# 5    16p       freqy   small      lruv     2.999131
# 6    24p       alpha   small      lruv     1.770852
# 7    20p       alpha   small      lruv     2.729165
# 8    16p       alpha   small      lruv     3.129690
# 9    24p       group  medium      lruv     1.724276

# %%
rp.summary_cat(df[["memory", "arrangement", "program", "algorithm"]])
# Out:
#        Variable Outcome  Count  Percent
# 0        memory     20p     27    33.33
# 1                   16p     27    33.33
# 2                   24p     27    33.33
# 3   arrangement   freqy     27    33.33
# 4                 group     27    33.33
# 5                 alpha     27    33.33
# 6       program  medium     27    33.33
# 7                 small     27    33.33
# 8                 large     27    33.33
# 9     algorithm    fifo     27    33.33
# 10                 lruv     27    33.33
# 11                 rand     27    33.33

# %%
rp.summary_cont(df["measurement"])
# Out:
#       Variable     N   Mean      SD      SE  95% Conf.  Interval
# 0  measurement  81.0  2.903  0.7794  0.0866     2.7306    3.0753

# %%
one = "C(memory) + C(arrangement) + C(program) + C(algorithm) +"
two_1 = "C(memory) * C(arrangement) + C(memory) * C(program) + C(memory) * C(algorithm) + " 
two_2 = "C(arrangement) * C(program) + C(arrangement) * C(algorithm) + "
two_3 = "C(program) *  C(algorithm) + "
two = two_1 + two_2 + two_3
three_1 = "C(memory) * C(arrangement) * C(program) + "
three_2 = "C(memory) * C(arrangement) * C(algorithm) + " 
three_3 = "C(memory) * C(program) * C(algorithm) + "
three_4 = "C(arrangement) * C(program) * C(algorithm)"
three = three_1 + three_2 + three_3 + three_4
formula = "measurement ~ " +one + two + three

# %%
model = ols(formula, df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            measurement   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     179.6
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           8.25e-16
# Time:                        21:44:23   Log-Likelihood:                 172.19
# No. Observations:                  81   AIC:                            -214.4
# Df Residuals:                      16   BIC:                            -58.73
# Df Model:                          64
# Covariance Type:            nonrobust
# =====================================================================================================================================
#                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                             4.2474      0.058     72.975      0.000       4.124       4.371
# C(memory)[T.20p]                                                     -0.2750      0.077     -3.568      0.003      -0.438      -0.112
# C(memory)[T.24p]                                                     -1.0199      0.077    -13.232      0.000      -1.183      -0.857
# C(arrangement)[T.freqy]                                              -0.1038      0.077     -1.346      0.197      -0.267       0.060
# C(arrangement)[T.group]                                              -0.3147      0.077     -4.083      0.001      -0.478      -0.151
# C(program)[T.medium]                                                 -0.4748      0.077     -6.160      0.000      -0.638      -0.311
# C(program)[T.small]                                                  -1.0391      0.077    -13.481      0.000      -1.203      -0.876
# C(algorithm)[T.lruv]                                                 -0.1214      0.077     -1.575      0.135      -0.285       0.042
# C(algorithm)[T.rand]                                                  0.0867      0.077      1.125      0.277      -0.077       0.250
# C(memory)[T.20p]:C(arrangement)[T.freqy]                             -0.3072      0.097     -3.172      0.006      -0.513      -0.102
# C(memory)[T.24p]:C(arrangement)[T.freqy]                             -0.4698      0.097     -4.851      0.000      -0.675      -0.264
# C(memory)[T.20p]:C(arrangement)[T.group]                             -1.0798      0.097    -11.148      0.000      -1.285      -0.874
# C(memory)[T.24p]:C(arrangement)[T.group]                             -0.5530      0.097     -5.710      0.000      -0.758      -0.348
# C(memory)[T.20p]:C(program)[T.medium]                                 0.0311      0.097      0.321      0.753      -0.174       0.236
# C(memory)[T.24p]:C(program)[T.medium]                                -0.4432      0.097     -4.576      0.000      -0.649      -0.238
# C(memory)[T.20p]:C(program)[T.small]                                  0.0079      0.097      0.082      0.936      -0.197       0.213
# C(memory)[T.24p]:C(program)[T.small]                                 -0.2691      0.097     -2.779      0.013      -0.474      -0.064
# C(memory)[T.20p]:C(algorithm)[T.lruv]                                -0.1201      0.097     -1.240      0.233      -0.325       0.085
# C(memory)[T.24p]:C(algorithm)[T.lruv]                                -0.1061      0.097     -1.096      0.289      -0.311       0.099
# C(memory)[T.20p]:C(algorithm)[T.rand]                                -0.0596      0.097     -0.616      0.547      -0.265       0.146
# C(memory)[T.24p]:C(algorithm)[T.rand]                                -0.1000      0.097     -1.032      0.317      -0.305       0.105
# C(arrangement)[T.freqy]:C(program)[T.medium]                          0.0166      0.097      0.171      0.866      -0.189       0.222
# C(arrangement)[T.group]:C(program)[T.medium]                          0.0401      0.097      0.414      0.684      -0.165       0.245
# C(arrangement)[T.freqy]:C(program)[T.small]                           0.0267      0.097      0.276      0.786      -0.179       0.232
# C(arrangement)[T.group]:C(program)[T.small]                           0.0303      0.097      0.313      0.758      -0.175       0.236
# C(arrangement)[T.freqy]:C(algorithm)[T.lruv]                         -0.0106      0.097     -0.110      0.914      -0.216       0.195
# C(arrangement)[T.group]:C(algorithm)[T.lruv]                         -0.0896      0.097     -0.925      0.369      -0.295       0.116
# C(arrangement)[T.freqy]:C(algorithm)[T.rand]                          0.0158      0.097      0.163      0.873      -0.190       0.221
# C(arrangement)[T.group]:C(algorithm)[T.rand]                          0.1285      0.097      1.327      0.203      -0.077       0.334
# C(program)[T.medium]:C(algorithm)[T.lruv]                             0.0076      0.097      0.078      0.938      -0.198       0.213
# C(program)[T.small]:C(algorithm)[T.lruv]                              0.0344      0.097      0.355      0.727      -0.171       0.240
# C(program)[T.medium]:C(algorithm)[T.rand]                             0.0258      0.097      0.266      0.794      -0.180       0.231
# C(program)[T.small]:C(algorithm)[T.rand]                              0.0743      0.097      0.767      0.454      -0.131       0.280
# C(memory)[T.20p]:C(arrangement)[T.freqy]:C(program)[T.medium]        -0.0396      0.106     -0.373      0.714      -0.264       0.185
# C(memory)[T.24p]:C(arrangement)[T.freqy]:C(program)[T.medium]         0.4722      0.106      4.450      0.000       0.247       0.697
# C(memory)[T.20p]:C(arrangement)[T.group]:C(program)[T.medium]        -0.0413      0.106     -0.389      0.702      -0.266       0.184
# C(memory)[T.24p]:C(arrangement)[T.group]:C(program)[T.medium]         0.5126      0.106      4.832      0.000       0.288       0.738
# C(memory)[T.20p]:C(arrangement)[T.freqy]:C(program)[T.small]          0.0435      0.106      0.410      0.687      -0.181       0.268
# C(memory)[T.24p]:C(arrangement)[T.freqy]:C(program)[T.small]          0.5225      0.106      4.924      0.000       0.298       0.747
# C(memory)[T.20p]:C(arrangement)[T.group]:C(program)[T.small]          0.2092      0.106      1.972      0.066      -0.016       0.434
# C(memory)[T.24p]:C(arrangement)[T.group]:C(program)[T.small]          0.6214      0.106      5.856      0.000       0.396       0.846
# C(memory)[T.20p]:C(arrangement)[T.freqy]:C(algorithm)[T.lruv]         0.0676      0.106      0.637      0.533      -0.157       0.293
# C(memory)[T.24p]:C(arrangement)[T.freqy]:C(algorithm)[T.lruv]         0.0337      0.106      0.317      0.755      -0.191       0.259
# C(memory)[T.20p]:C(arrangement)[T.group]:C(algorithm)[T.lruv]         0.1147      0.106      1.081      0.296      -0.110       0.340
# C(memory)[T.24p]:C(arrangement)[T.group]:C(algorithm)[T.lruv]         0.0698      0.106      0.658      0.520      -0.155       0.295
# C(memory)[T.20p]:C(arrangement)[T.freqy]:C(algorithm)[T.rand]         0.1308      0.106      1.233      0.235      -0.094       0.356
# C(memory)[T.24p]:C(arrangement)[T.freqy]:C(algorithm)[T.rand]         0.0329      0.106      0.310      0.761      -0.192       0.258
# C(memory)[T.20p]:C(arrangement)[T.group]:C(algorithm)[T.rand]         0.4691      0.106      4.421      0.000       0.244       0.694
# C(memory)[T.24p]:C(arrangement)[T.group]:C(algorithm)[T.rand]        -0.0043      0.106     -0.041      0.968      -0.229       0.221
# C(memory)[T.20p]:C(program)[T.medium]:C(algorithm)[T.lruv]           -0.0181      0.106     -0.171      0.867      -0.243       0.207
# C(memory)[T.24p]:C(program)[T.medium]:C(algorithm)[T.lruv]           -0.0019      0.106     -0.018      0.986      -0.227       0.223
# C(memory)[T.20p]:C(program)[T.small]:C(algorithm)[T.lruv]             0.0173      0.106      0.163      0.873      -0.208       0.242
# C(memory)[T.24p]:C(program)[T.small]:C(algorithm)[T.lruv]             0.0312      0.106      0.294      0.773      -0.194       0.256
# C(memory)[T.20p]:C(program)[T.medium]:C(algorithm)[T.rand]           -0.0920      0.106     -0.867      0.399      -0.317       0.133
# C(memory)[T.24p]:C(program)[T.medium]:C(algorithm)[T.rand]            0.1338      0.106      1.261      0.225      -0.091       0.359
# C(memory)[T.20p]:C(program)[T.small]:C(algorithm)[T.rand]            -0.1714      0.106     -1.616      0.126      -0.396       0.053
# C(memory)[T.24p]:C(program)[T.small]:C(algorithm)[T.rand]             0.0889      0.106      0.838      0.415      -0.136       0.314
# C(arrangement)[T.freqy]:C(program)[T.medium]:C(algorithm)[T.lruv]     0.0038      0.106      0.036      0.972      -0.221       0.229
# C(arrangement)[T.group]:C(program)[T.medium]:C(algorithm)[T.lruv]    -0.0140      0.106     -0.132      0.897      -0.239       0.211
# C(arrangement)[T.freqy]:C(program)[T.small]:C(algorithm)[T.lruv]     -0.0514      0.106     -0.485      0.634      -0.276       0.173
# C(arrangement)[T.group]:C(program)[T.small]:C(algorithm)[T.lruv]      0.0090      0.106      0.085      0.933      -0.216       0.234
# C(arrangement)[T.freqy]:C(program)[T.medium]:C(algorithm)[T.rand]    -0.0351      0.106     -0.331      0.745      -0.260       0.190
# C(arrangement)[T.group]:C(program)[T.medium]:C(algorithm)[T.rand]    -0.2920      0.106     -2.752      0.014      -0.517      -0.067
# C(arrangement)[T.freqy]:C(program)[T.small]:C(algorithm)[T.rand]     -0.0336      0.106     -0.316      0.756      -0.259       0.191
# C(arrangement)[T.group]:C(program)[T.small]:C(algorithm)[T.rand]     -0.2232      0.106     -2.103      0.052      -0.448       0.002
# ==============================================================================
# Omnibus:                        6.021   Durbin-Watson:                   3.325
# Prob(Omnibus):                  0.049   Jarque-Bera (JB):                9.608
# Skew:                           0.057   Prob(JB):                      0.00819
# Kurtosis:                       4.683   Cond. No.                         72.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
res = sm.stats.anova_lm(model, typ = 3)
res
# Out:
#                                            sum_sq    df            F  \
# Intercept                               22.481423   1.0  5325.316967
# C(memory)                                0.791398   2.0    93.731778
# C(arrangement)                           0.073088   2.0     8.656386
# C(program)                               0.769138   2.0    91.095321
# C(algorithm)                             0.031070   2.0     3.679932
# C(memory):C(arrangement)                 0.633938   4.0    37.541203
# C(memory):C(program)                     0.128265   4.0     7.595717
# C(memory):C(algorithm)                   0.009543   4.0     0.565137
# C(arrangement):C(program)                0.000937   4.0     0.055489
# C(arrangement):C(algorithm)              0.025770   4.0     1.526069
# C(program):C(algorithm)                  0.002576   4.0     0.152576
# C(memory):C(arrangement):C(program)      0.261714   8.0     7.749231
# C(memory):C(arrangement):C(algorithm)    0.145017   8.0     4.293899
# C(memory):C(program):C(algorithm)        0.042718   8.0     1.264861
# C(arrangement):C(program):C(algorithm)   0.058154   8.0     1.721911
# Residual                                 0.067546  16.0          NaN
#
#                                               PR(>F)
# Intercept                               1.274825e-21
# C(memory)                               1.462402e-09
# C(arrangement)                          2.831873e-03
# C(program)                              1.804242e-09
# C(algorithm)                            4.843925e-02
# C(memory):C(arrangement)                6.081775e-08
# C(memory):C(program)                    1.251148e-03
# C(memory):C(algorithm)                  6.914797e-01
# C(arrangement):C(program)               9.936778e-01
# C(arrangement):C(algorithm)             2.418549e-01
# C(program):C(algorithm)                 9.590767e-01
# C(memory):C(arrangement):C(program)     2.834531e-04
# C(memory):C(arrangement):C(algorithm)   6.374877e-03
# C(memory):C(program):C(algorithm)       3.268057e-01
# C(arrangement):C(program):C(algorithm)  1.688594e-01
# Residual                                         NaN
